# %% [markdown]
# # Quickstart: Qiskit + LLM Hybrid
#
# This notebook guides you through environment setup, data prep, and a dry-run of the hybrid pipeline.
# Run the cells in order. If a package is missing, install it with `pip`.

# %%
# !pip install -U qiskit qiskit-machine-learning numpy pandas scikit-learn transformers datasets accelerate torch --quiet
import sys, platform
print('Python', sys.version)
print(platform.platform())

# %% [markdown]
# ## Next steps
# - Fill in your dataset under `data/`
# - Implement training/evaluation in `src/`
# - (Optional) Use `qiskit/` for quantum circuits and feature maps.
