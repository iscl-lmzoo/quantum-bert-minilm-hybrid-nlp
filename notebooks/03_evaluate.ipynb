# %% [markdown]
# # Evaluate: Metrics and Curves
# Run this after training to generate metrics, PR/ROC curves, and a predictions CSV.

# %%
from src.evaluate import evaluate
res = evaluate(dataset_path='data/toy_sentiment.csv',
               report_path='models/eval_metrics.json',
               cm_path='models/confusion_matrix.png',
               pr_path='models/pr_curve.png',
               roc_path='models/roc_curve.png',
               preds_csv='models/predictions.csv')
res

# %% [markdown]
# Artifacts written to `models/`: `eval_metrics.json`, `confusion_matrix.png`, `pr_curve.png`, `roc_curve.png`, `predictions.csv`.
