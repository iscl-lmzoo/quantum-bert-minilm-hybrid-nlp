# %% [markdown]
# # Demo: Hybrid Sentiment (Tiny) with Qiskit + LLM
# This notebook runs the training pipeline on a tiny toy dataset.

# %%
# !pip install -U qiskit qiskit-machine-learning sentence-transformers transformers datasets accelerate torch scikit-learn
import sys, platform
print('Python:', sys.version)
print(platform.platform())

# %%
from src.train_hybrid import train
res = train()
res
